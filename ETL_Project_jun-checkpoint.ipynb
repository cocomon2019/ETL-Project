# %%
import pandas as pd

# %%
USvideos_data = pd.read_csv('Resources/USvideos.csv')
USvideos_data['country'] = 'USA'

# Find possible missing values
USvideos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
# video_id                  200 non-null object
# trending_date             200 non-null object
# title                     200 non-null object
# channel_title             200 non-null object
# category_id               200 non-null int64
# publish_time              200 non-null object
# tags                      200 non-null object
# views                     200 non-null int64
# likes                     200 non-null int64
# dislikes                  200 non-null int64
# comment_count             200 non-null int64
# thumbnail_link            200 non-null object
# comments_disabled         200 non-null bool
# ratings_disabled          200 non-null bool
# video_error_or_removed    200 non-null bool
# description               197 non-null object
# country                   200 non-null object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 22.5+ KB

# %%
# Count the null columns
null_columns = USvideos_data.columns[USvideos_data.isnull().any()]
print(USvideos_data[null_columns].isnull().sum())

# Locate and inspect null values within data
USvideos_data[USvideos_data.isnull().any(axis=1)][null_columns]
# Out:
# description    3
# dtype: int64
#     description
# 17          NaN
# 58          NaN
# 145         NaN

# %%
# Complete the null data value
datatype_USVideos = USvideos_data.dtypes.to_dict()
USvideos_data['description'].fillna('None', inplace=True, downcast=datatype_USVideos)
USvideos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
# video_id                  200 non-null object
# trending_date             200 non-null object
# title                     200 non-null object
# channel_title             200 non-null object
# category_id               200 non-null int64
# publish_time              200 non-null object
# tags                      200 non-null object
# views                     200 non-null int64
# likes                     200 non-null int64
# dislikes                  200 non-null int64
# comment_count             200 non-null int64
# thumbnail_link            200 non-null object
# comments_disabled         200 non-null bool
# ratings_disabled          200 non-null bool
# video_error_or_removed    200 non-null bool
# description               200 non-null object
# country                   200 non-null object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 22.5+ KB

# %%
# Look in to CAvideos.csv
CAvideos_data = pd.read_csv('Resources/CAvideos.csv')
CAvideos_data['country'] = 'Canada'

CAvideos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 17 columns):
# video_id                  199 non-null object
# trending_date             199 non-null object
# title                     199 non-null object
# channel_title             199 non-null object
# category_id               199 non-null int64
# publish_time              199 non-null object
# tags                      199 non-null object
# views                     199 non-null int64
# likes                     199 non-null int64
# dislikes                  199 non-null int64
# comment_count             199 non-null int64
# thumbnail_link            199 non-null object
# comments_disabled         199 non-null bool
# ratings_disabled          199 non-null bool
# video_error_or_removed    199 non-null bool
# description               193 non-null object
# country                   199 non-null object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 22.4+ KB

# %%
# Find and inspect null data
CAvideos_data.loc[CAvideos_data['description'].isnull()]

# Fill in the null data
datatype_CAVideos = USvideos_data.dtypes.to_dict()
CAvideos_data['description'].fillna('None', inplace=True, downcast=datatype_CAVideos)
print(CAvideos_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 17 columns):
# video_id                  199 non-null object
# trending_date             199 non-null object
# title                     199 non-null object
# channel_title             199 non-null object
# category_id               199 non-null int64
# publish_time              199 non-null object
# tags                      199 non-null object
# views                     199 non-null int64
# likes                     199 non-null int64
# dislikes                  199 non-null int64
# comment_count             199 non-null int64
# thumbnail_link            199 non-null object
# comments_disabled         199 non-null bool
# ratings_disabled          199 non-null bool
# video_error_or_removed    199 non-null bool
# description               199 non-null object
# country                   199 non-null object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 22.4+ KB
# None

# %%
# Combine two dataset
combine_df = pd.merge(USvideos_data,CAvideos_data, how='outer')
combine_df.head(3)
# Out:
#       video_id trending_date  \
# 0  1ZAPwfrtAFY      17.13.11
# 1  5qpjK5DgCt4      17.13.11
# 2  puqaWrEC7tY      17.13.11
#
#                                                title          channel_title  \
# 0  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 1  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 2                   Nickleback Lyrics: Real or Fake?  Good Mythical Morning
#
#    category_id              publish_time  \
# 0           24  2017-11-13T07:30:00.000Z
# 1           23  2017-11-12T19:05:24.000Z
# 2           24  2017-11-13T11:00:04.000Z
#
#                                                 tags    views   likes  \
# 0  last week tonight trump presidency|"last week ...   993345   65551
# 1  racist superman|"rudy"|"mancuso"|"king"|"bach"...  2568721  132724
# 2  rhett and link|"gmm"|"good mythical morning"|"...   118585    6183
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      3544           8128  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 1      4495           7494  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 2       361           1374  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
# 2             False            False                  False
#
#                                          description country
# 0  One year after the presidential election, John...     USA
# 1  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...     USA
# 2  Today we find out if Link is a Nickelback amat...     USA

# %%
combine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399 entries, 0 to 398
# Data columns (total 17 columns):
# video_id                  399 non-null object
# trending_date             399 non-null object
# title                     399 non-null object
# channel_title             399 non-null object
# category_id               399 non-null int64
# publish_time              399 non-null object
# tags                      399 non-null object
# views                     399 non-null int64
# likes                     399 non-null int64
# dislikes                  399 non-null int64
# comment_count             399 non-null int64
# thumbnail_link            399 non-null object
# comments_disabled         399 non-null object
# ratings_disabled          399 non-null object
# video_error_or_removed    399 non-null object
# description               399 non-null object
# country                   399 non-null object
# dtypes: int64(5), object(12)
# memory usage: 56.1+ KB

# %%
find_dupe = combine_df[combine_df.duplicated(['video_id'],keep=False)]

# %%
print(find_dupe.video_id.count())
find_dupe.sort_values(['video_id']).head(4)
# Out:
# 34
#         video_id trending_date  \
# 289  0PpNlNJ6Nng      17.13.11
# 18   0PpNlNJ6Nng      17.13.11
# 201  2Vv-BfVoq4g      17.13.11
# 35   2Vv-BfVoq4g      17.13.11
#
#                                                  title      channel_title  \
# 289  Will It Watermarble?! Sister Edition | Waterma...  Simply Nailogical
# 18   Will It Watermarble?! Sister Edition | Waterma...  Simply Nailogical
# 201        Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# 35         Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
#
#      category_id              publish_time  \
# 289           24  2017-11-11T19:03:43.000Z
# 18            24  2017-11-11T19:03:43.000Z
# 201           10  2017-11-09T11:04:14.000Z
# 35            10  2017-11-09T11:04:14.000Z
#
#                                                   tags     views    likes  \
# 289  nails|"nail art"|"nail tutorial"|"beauty tutor...   1788339    97507
# 18   nails|"nail art"|"nail tutorial"|"beauty tutor...   1788339    97507
# 201  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  31553923  1604688
# 35   edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  31553923  1604674
#
#      dislikes  comment_count                                  thumbnail_link  \
# 289      1287          11635  https://i.ytimg.com/vi/0PpNlNJ6Nng/default.jpg
# 18       1287          11635  https://i.ytimg.com/vi/0PpNlNJ6Nng/default.jpg
# 201     20482          84293  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
# 35      20480          84293  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#     comments_disabled ratings_disabled video_error_or_removed  \
# 289             False            False                  False
# 18              False            False                  False
# 201             False            False                  False
# 35              False            False                  False
#
#                                            description country
# 289  Guess who's back... back again... Jenny's back...  Canada
# 18   Guess who's back... back again... Jenny's back...     USA
# 201  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...  Canada
# 35   🎧: https://ad.gt/yt-perfect\n💰: https://atlant...     USA
